# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **MACHINE LEARNING INTERNSHIP (TASK 2)**
#
# **Project Title: Movie Recommendation System**

# %% [markdown]
# # **Project Description: Build a basic movie recommendation system that suggests movies**
# to users based on their viewing history or preferences. This project will introduce you to
# the concepts of collaborative filtering and content-based recommendation.
#
# **Steps  Implement:**
# Data Collection: Gather movie data, including titles, genres, and user ratings. You can
# find movie datasets on websites like Kaggle or use publicly available data sources.
#
# **Data Preprocessing:** Clean and preprocess the data, handling missing values and
# ensuring it's in a suitable format for your recommendation system.
# Exploratory Data Analysis: Explore the data to gain insights, such as the distribution of
# movie ratings, the most popular genres, and user preferences.
#
# **Collaborative Filtering:** Implement a collaborative filtering algorithm, which
# recommends movies to users based on the preferences of other users with similar tastes.
# You can use techniques like user-based or item-based collaborative filtering.
#
# **Content-Based Filtering:** Implement a content-based recommendation system that
# suggests movies similar to the ones a user has already watched and liked. You can use
# movie genres, directors, and actors as features.
#
# **User Interface:** Create a simple user interface where users can input their movie
# preferences or view their recommended movies. This could be a command-line interface
# or a basic web application.
#
# **Recommendation Engine:** Combine the collaborative filtering and content-based
# filtering approaches to provide more accurate and diverse recommendations.
#
# **Evaluation:** Evaluate the recommendation system's performance using metrics like Mean
# Absolute Error (MAE) or Root Mean Squared Error (RMSE) for collaborative filtering and
# precision, recall, or F1-score for content-based filtering.
# Testing: Test the recommendation system with sample users and collect feedback to
# improve its accuracy and user experience.
#
# **Documentation:** Document your project, including the data sources, algorithms used,
# and any challenges you faced. This documentation will be valuable for future reference.

# %% [markdown]
# # **Movie Recommendation System using Collaborative Filtering**

# %% [markdown]
# **Introduction:**
# In the digital era, personalized content recommendations have become integral to user satisfaction. This code implements a collaborative filtering-based movie recommendation system, a powerful technique that tailors suggestions to individual user preferences. Collaborative filtering works by analyzing the behaviors and preferences of users with similar tastes, offering a more personalized and engaging experience.
#
# **Step 1: Data Loading and Merging**
# Two datasets are loaded - one containing movie titles and the other user ratings. Through merging based on a shared identifier, a consolidated DataFrame is created, forming the foundation for the recommendation system.
#
# **Step 2: Exploratory Data Analysis**
# - The merged DataFrame's structure and information are explored.
# - Duplicate rows are identified and addressed.
# - Mean ratings and user counts per movie are calculated, establishing a baseline for collaborative filtering.
#
# **Step 3: Collaborative Filtering**
# - A movie correlation function is defined, leveraging the user-item ratings matrix.
# - This function identifies similar movies based on user ratings, facilitating personalized recommendations.
# - Example usage demonstrates how the system recommends movies correlated with a specific title.
#
# **Use Cases:**
# - Personalized Recommendations: By understanding user preferences, the system suggests movies tailored to individual tastes.
# - Enhanced User Experience: Users can discover and enjoy new movies that align with their cinematic preferences.
# - Optimizing Content Delivery: Content providers can use collaborative filtering to refine suggestions, leading to increased user engagement.
# - Community Building: Users with similar movie tastes discover and engage with shared content, fostering a sense of community.
#
# **Conclusion:**
# This collaborative filtering-based recommendation system enhances the user experience by offering personalized movie suggestions. By leveraging the collective wisdom of users with similar tastes, the system optimizes content delivery, encouraging community building within the user base.

# %%
import pandas as pd

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df_title = pd.read_csv('/content/Movie_Id_Titles.csv')
df_dataset = pd.read_csv('/content/Dataset.csv')

df_merged = pd.merge(df_title, df_dataset, left_on = 'item_id', right_on = 'item_id')
df_merged.head()
# Out:
#    item_id             title  user_id  rating  timestamp
# 0        1  Toy Story (1995)      308       4  887736532
# 1        1  Toy Story (1995)      287       5  875334088
# 2        1  Toy Story (1995)      148       4  877019411
# 3        1  Toy Story (1995)      280       4  891700426
# 4        1  Toy Story (1995)       66       3  883601324
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['user_id'].plot(kind='hist', bins=20, title='user_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['rating'].plot(kind='hist', bins=20, title='rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['timestamp'].plot(kind='hist', bins=20, title='timestamp')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100003 entries, 0 to 100002
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   item_id    100003 non-null  int64
#  1   title      100003 non-null  object
#  2   user_id    100003 non-null  int64
#  3   rating     100003 non-null  int64
#  4   timestamp  100003 non-null  int64
# dtypes: int64(4), object(1)
# memory usage: 4.6+ MB

# %%
df_merged.duplicated().sum()
# Out:
# 0

# %%
group = df_merged.groupby(['title']).agg({'rating' : 'mean', 'user_id' : 'count' })
group.head()
# Out:
#                              rating  user_id
# title
# 'Til There Was You (1997)  2.333333        9
# 1-900 (1994)               2.600000        5
# 101 Dalmatians (1996)      2.908257      109
# 12 Angry Men (1957)        4.344000      125
# 187 (1997)                 3.024390       41
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['rating'].plot(kind='hist', bins=20, title='rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['user_id'].plot(kind='hist', bins=20, title='user_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
pivot = df_merged.pivot_table(index = 'user_id',columns = 'title', values = 'rating')
pivot.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
def movie_correlation(movie_title, n) :
    movie_rating = pivot[movie_title]
    similar_to_movie = pivot.corrwith(movie_rating)
    corr_ = pd.DataFrame(similar_to_movie, columns = ['correlation'])
    corr_.dropna(inplace=True)
    return corr_.sort_values(by = 'correlation',ascending=False).head(n)


movie_correlation('12 Angry Men (1957)', n = 10)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
#                                                     correlation
# title
# Dingo (1992)                                                1.0
# Nina Takes a Lover (1994)                                   1.0
# Surviving Picasso (1996)                                    1.0
# American Dream (1990)                                       1.0
# FairyTale: A True Story (1997)                              1.0
# Grace of My Heart (1996)                                    1.0
# Dream With the Fishes (1997)                                1.0
# Double Happiness (1994)                                     1.0
# Gridlock'd (1997)                                           1.0
# ...

# %%
def recommend_movie(user_id, pivot, user_similarity, n=1):
    user_ratings = pivot.loc[user_id]
    unrated_movies = user_ratings[user_ratings.isna()].index  # Movies not yet rated by the user

    if unrated_movies.empty:
        return "No unrated movies to recommend."

    recommendations = []
    for movie_title in unrated_movies:
        prediction = predict_user_based(user_id, movie_title, pivot, user_similarity)
        recommendations.append((movie_title, prediction))

    recommendations.sort(key=lambda x: x[1], reverse=True)  # Sort by predicted rating
    top_recommendations = recommendations[:n]

    return top_recommendations

# %%
# Assuming you have already calculated user similarity and have a pivot table
new_movie_title = 'American Dream (1990)'  # Replace with the title of the new movie

# Calculate correlation with the new movie
new_movie_correlation = movie_correlation(new_movie_title, n=10)

# Display the top 10 movies correlated with the new movie
print("Top 10 movies correlated with '{}':".format(new_movie_title))
print(new_movie_correlation)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# Top 10 movies correlated with 'American Dream (1990)':
#                                              correlation
# title
# 12 Angry Men (1957)                                  1.0
# Once Were Warriors (1994)                            1.0
# Muriel's Wedding (1994)                              1.0
# Mute Witness (1994)                                  1.0
# My Crazy Life (Mi vida loca) (1993)                  1.0
# My Family (1995)                                     1.0
# My Left Foot (1989)                                  1.0
# My Life as a Dog (Mitt liv som hund) (1985)          1.0
# My Own Private Idaho (1991)                          1.0
# ...

# %%
def recommend_movies_for_new_movie(new_movie_title, pivot, correlation_matrix, n=5):
    # Find correlation for the new movie
    new_movie_correlation = correlation_matrix[new_movie_title].dropna()

    # Exclude the new movie itself
    new_movie_correlation = new_movie_correlation[new_movie_correlation.index != new_movie_title]

    # Sort movies by correlation in descending order
    correlated_movies = new_movie_correlation.sort_values(ascending=False)

    # Get the top N correlated movies
    top_recommendations = correlated_movies.head(n)

    return top_recommendations

# %%
def recommend_movies_for_new_movie(new_movie_title, pivot, correlation_matrix, n=5):
    # Try to find the exact match
    try:
        new_movie_correlation = correlation_matrix[new_movie_title].dropna()
    except KeyError:
        # If not found, try to find a case-insensitive match
        matching_titles = [title for title in correlation_matrix.index if title.lower() == new_movie_title.lower()]
        if not matching_titles:
            return f"No correlation information found for '{new_movie_title}'."

        # Use the first matching title found
        new_movie_correlation = correlation_matrix.loc[matching_titles[0]].dropna()

    # Exclude the new movie itself
    new_movie_correlation = new_movie_correlation[new_movie_correlation.index != new_movie_title]

    # Sort movies by correlation in descending order
    correlated_movies = new_movie_correlation.sort_values(ascending=False)

    # Get the top N correlated movies
    top_recommendations = correlated_movies.head(n)

    return top_recommendations

# %%
new_movie_title = 'My Family (1995)'
top_recommendations = recommend_movies_for_new_movie(new_movie_title, pivot, new_movie_correlation, n=5)

print(f"Top 5 movies recommended for '{new_movie_title}':")
print(top_recommendations)
# Out:
# Top 5 movies recommended for 'My Family (1995)':
# correlation    1.0
# Name: My Family (1995), dtype: float64
